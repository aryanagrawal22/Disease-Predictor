# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
stroke = pd.read_csv("./Datasets/healthcare-dataset-stroke-data.csv")
stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
stroke["stroke"].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
stroke.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
stroke = stroke.dropna()

# %%
stroke.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
stroke = stroke.drop("id", axis = 1)

# %%
stroke["stroke"].value_counts()
# Out:
# 0    4700
# 1     209
# Name: stroke, dtype: int64

# %%
N = 100
df = stroke.drop(np.random.choice(stroke.index[stroke['stroke'].eq(0)], 1000))

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5098    Male   9.0             0              0           No       children
# 5102  Female  57.0             0              0          Yes        Private
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
df = df.drop(np.random.choice(df.index[df['stroke'].eq(0)], 1000))

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5097    Male  68.0             0              0          Yes  Self-employed
# 5098    Male   9.0             0              0           No       children
# 5102  Female  57.0             0              0          Yes        Private
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
#
# ...

# %%
df = df.drop(np.random.choice(df.index[df['stroke'].eq(0)], 1000))

# %%
df["stroke"].value_counts()
# Out:
# 0    2081
# 1     209
# Name: stroke, dtype: int64

# %%
df = df.drop(np.random.choice(df.index[df['stroke'].eq(0)], 300))

# %%
df["stroke"].value_counts()
# Out:
# 0    1796
# 1     209
# Name: stroke, dtype: int64

# %%
209/766
# Out:
# 0.27284595300261094

# %%
df.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5094    Male  13.0             0              0           No       children
# 5096    Male  57.0             0              0          Yes       Govt_job
# 5098    Male   9.0             0              0           No       children
# 5102  Female  57.0             0              0          Yes        Private
# 5107  Female  35.0             0              0          Yes  Self-employed
#
# ...

# %%
df.to_csv(r'Datasets\Edited_Stroke_Data.csv')

# %%
df["smoking_status"].value_counts()
# Out:
# never smoked       763
# Unknown            570
# formerly smoked    358
# smokes             314
# Name: smoking_status, dtype: int64

# %%
df = df[df.smoking_status != "Unknown"]

# %%
df["smoking_status"].value_counts()
# Out:
# never smoked       763
# formerly smoked    358
# smokes             314
# Name: smoking_status, dtype: int64

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5087  Female  63.0             0              0          Yes  Self-employed
# 5092    Male  76.0             0              0          Yes       Govt_job
# 5096    Male  57.0             0              0          Yes       Govt_job
# 5102  Female  57.0             0              0          Yes        Private
# 5107  Female  35.0             0              0          Yes  Self-employed
#
# ...

# %%
df["stroke"].value_counts()
# Out:
# 0    1255
# 1     180
# Name: stroke, dtype: int64

# %%
df
# Out:
#       Unnamed: 0  gender   age  hypertension  heart_disease ever_married  \
# 0              0    Male  67.0             0              1          Yes
# 1              2    Male  80.0             0              1          Yes
# 2              3  Female  49.0             0              0          Yes
# 3              4  Female  79.0             1              0          Yes
# 4              5    Male  81.0             0              0          Yes
# ...          ...     ...   ...           ...            ...          ...
# 1430        5087  Female  63.0             0              0          Yes
# 1431        5092    Male  76.0             0              0          Yes
# 1432        5096    Male  57.0             0              0          Yes
# 1433        5102  Female  57.0             0              0          Yes
# 1434        5107  Female  35.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df["stroke"].value_counts()
# Out:
# 0    1255
# 1     180
# Name: stroke, dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df = df.drop(np.random.choice(df.index[df['stroke'].eq(0)], 300))

# %%
df["stroke"].value_counts()
# Out:
# 0    986
# 1    180
# Name: stroke, dtype: int64

# %%
df = df.drop(np.random.choice(df.index[df['stroke'].eq(0)], 300))

# %%
df["stroke"].value_counts()
# Out:
# 0    479
# 1    180
# Name: stroke, dtype: int64
